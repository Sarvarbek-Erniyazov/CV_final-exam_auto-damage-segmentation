# %%
# !nvidia-smi
# Out:
# Fri Jun 19 09:32:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8             14W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics roboflow

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="????")
project = rf.workspace("sarvarbeks-workspace").project("car-parts-segmentation-2atbn")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 95.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to Car-Parts-Segmentation-1 in yolov8:: 100%|██████████| 3011/3011 [00:00<00:00, 5113.50it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    project="auto-damage-segmentation",
    name="car-parts",
    save=True
)
# Out:
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    project="auto-damage-segmentation",
    name="car-parts",
    save=True
)
# Out:
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import glob

weights = glob.glob("/content/runs/segment/auto-damage-segmentation/car-parts*/weights/best.pt")
print(weights[0])
# Out:
# /content/runs/segment/auto-damage-segmentation/car-parts-2/weights/best.pt

# %%
model = YOLO(weights[0])
model.export(format="onnx")
print("ONNX export tayyor!")
# Out:
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLOv8n-seg summary (fused): 86 layers, 3,261,574 parameters, 0 gradients, 11.4 GFLOPs
#
# PyTorch: starting from '/content/runs/segment/auto-damage-segmentation/car-parts-2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 54, 8400), (1, 32, 160, 160)) (6.5 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 294ms
# Prepared 4 packages in 1.81s
# Installed 4 packages in 262ms
#  + colorama==0.4.6
#  + onnx==1.22.0
#  + onnxruntime==1.27.0
#  + onnxslim==0.1.94
#
# requirements: AutoUpdate success ✅ 3.0s
# ...

# %%
from google.colab import files

files.download("/content/runs/segment/auto-damage-segmentation/car-parts-2/weights/best.pt")
files.download("/content/runs/segment/auto-damage-segmentation/car-parts-2/weights/best.onnx")
